# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('4strains_wreps.xlsx', sheet_name='RPMI_37C', engine='openpyxl')
df
time = df.loc[:, df.columns.str.contains('Time')]
df = df.loc[:, ~df.iloc[0].isna()]
df.columns = df.iloc[0]
df = df.drop(index=0)
df
# Out:
# 0     Rep1 Rep 1 Average     Rep2 Rep2 Average      Rep3 Rep3 Average    Rep1  \
# 1    0.003      0.004583  0.02878     0.031417 -0.003667     0.002667   0.005
# 2    0.003      0.005167  0.02861     0.031108 -0.003167     0.002167  0.0045
# 3   0.0035        0.0055  0.02872     0.030947 -0.002333     0.002333   0.005
# 4   0.0045      0.005833  0.02928     0.031333 -0.002667     0.002167  0.0055
# 5   0.0055      0.006917  0.03017     0.031862    -0.001     0.002667  0.0065
# ..     ...           ...      ...          ...       ...          ...     ...
# 68   0.352         0.284  0.38178     0.331443  0.389333     0.306333  0.3075
# 69  0.3525      0.284583  0.38233      0.33197    0.3895     0.306333  0.3075
# 70   0.352      0.284417  0.38206     0.331917  0.389167     0.306333   0.307
# 71   0.351      0.285167  0.38139     0.332057  0.388167        0.306   0.306
# 72  0.3505      0.284333  0.38122     0.331833  0.388167     0.306167  0.3045
#
# ...

# %%
time
time = time.drop(time.index[0]).reset_index(drop=True)
time
print(len(df))
# Out:
# 72

# %%
df = df.loc[:, df.columns.str.contains('Average')]
df.head()
df.index = time['Time']
df
# Out:
# 0         Rep 1 Average Rep2 Average Rep3 Average Rep1 Average Rep2 Average  \
# Time
# 0.333334       0.004583     0.031417     0.002667     0.005083     0.032638
# 0.666667       0.005167     0.031108     0.002167     0.004917     0.032138
# 1.000000         0.0055     0.030947     0.002333     0.005083     0.032748
# 1.333333       0.005833     0.031333     0.002167     0.005583     0.032807
# 1.666667       0.006917     0.031862     0.002667     0.006167      0.03322
# ...                 ...          ...          ...          ...          ...
# 22.666670         0.284     0.331443     0.306333      0.25475     0.325305
# 23.000000      0.284583      0.33197     0.306333     0.255167     0.325223
# 23.333340      0.284417     0.331917     0.306333     0.254583     0.324583
# 23.666670      0.285167     0.332057        0.306     0.255083     0.324528
# 24.000000      0.284333     0.331833     0.306167     0.253917     0.323918
#
# ...

# %%
strain_names = ['D1', 'AE2', '110', '111', '112', 'CBS138', 'BG2']
new_columns = []

for i, col in enumerate(df.columns):
    strain = strain_names[i // 3]
    new_columns.append(f"{strain} {col}")

df.columns = new_columns
df.head()
# Out:
#          D1 Rep 1 Average D1 Rep2 Average D1 Rep3 Average AE2 Rep1 Average  \
# Time
# 0.333334         0.004583        0.031417        0.002667         0.005083
# 0.666667         0.005167        0.031108        0.002167         0.004917
# 1.000000           0.0055        0.030947        0.002333         0.005083
# 1.333333         0.005833        0.031333        0.002167         0.005583
# 1.666667         0.006917        0.031862        0.002667         0.006167
#
#          AE2 Rep2 Average AE2 Rep3 Average 110 Rep1 Average 110 Rep2 Average  \
# Time
# 0.333334         0.032638         0.003833          0.00824         0.004208
# 0.666667         0.032138           0.0035          0.00674         0.019206
# 1.000000         0.032748         0.005167          0.00654         0.019606
# 1.333333         0.032807         0.004833          0.00604         0.019606
# 1.666667          0.03322           0.0055          0.00584         0.019606
#
# ...

# %%
df.to_excel('prcsd_RPMI37.xlsx')
